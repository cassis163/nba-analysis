# %%
import sys

# !conda install --yes --prefix {sys.prefix} pandas bs4
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import string

def get_tables(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    tables = soup.find_all("table", class_="wikitable sortable", recursive=True)
    
    return tables

def get_nba_tables(url):
    tables = get_tables(url)
    
    nba_tables = []
    for table in tables:
        ths = table.find_all("th")
        for th in ths:
            if th.text == "PPG\n":
                nba_tables.append(table)
                break
    
    return nba_tables

def clean_str(s):
    s = s.rstrip("\n")
    s = s.lstrip()
    s = s.lstrip("-")
    s = s.replace("*", "")
    s = s.replace("†", "")
    
    nan_values = ["–", "—", "...", "NaN."]
    for nan_value in nan_values:
        s = s.replace(nan_value, "NaN")
    
    if len(s) == 0: s = "NaN"
    
    return s

def create_df_from_table(table):
    ths = table.find_all("th")
    headers = [th.get_text().rstrip('\n') for th in ths]
    
    trs = table.find("tbody").find_all("tr", class_="")
    # Get all rows in the table in a nested array format
    rows = [[clean_str(td.get_text()) for td in tr.find_all("td")] for tr in trs][1:]
    
    df = pd.DataFrame(data=rows, columns=headers)
    
    return df

def get_dfs_from_tables(tables):
    dfs = []
    for table in tables:
        df = create_df_from_table(table)
        dfs.append(df)
    
    return dfs

# %%
best_players_not_in_top_50 = [
    "Lebron James",
    "Kobe Bryant",
    "James Harden",
    "Giannis Antetokounmpo",
    "Kevin Durant",
    "Luka Doncic",
    "Zion Williamson",
    "Stephen Curry",
    "Allen Iverson",
    "Joel Embiid",
    "Dwayne Wade",
    "Dwight Howard",
    "Dominique Wilkins",
    "Steve Nash",
    "Ray Allen",
    "Gary Payton",
    "Sam Jones (basketball, born 1933)",
    "Kevin McHale (basketball)",
]

def get_player_url(player_name):
    return "https://en.wikipedia.org/wiki/" + player_name.replace(" ", "_")

def get_best_players():
    url = "https://en.wikipedia.org/wiki/50_Greatest_Players_in_NBA_History"
    df = get_dfs_from_tables(get_tables(url))[0]
    best_players = df['Name'].values.tolist()
    best_players.extend(best_players_not_in_top_50)
    
    return best_players

def fix_dtypes(df):
    def get_dtype(col_name):
        if col_name == "Year" or col_name == "Team" or col_name == "Season" or col_name == "League":
            return "string"
        else:
            return "float64"
    
    for col_name in df.columns:
        col = df[col_name]
        df[col_name] = col.astype(get_dtype(col_name))

def get_and_write_data(player_name):
    def get_name(i):
        if i == 0:
            return "Regular season"
        elif i == 1:
            return "Playoffs"
        else:
            return "Unknown_" + str(i - 1)
    
    url = get_player_url(player_name)
    dfs = get_dfs_from_tables(get_nba_tables(url))
    for i, df in enumerate(dfs):
        fix_dtypes(df)
        file_name = "./data/" + player_name + "_" + get_name(i) + ".csv"
        file_name = file_name.replace(" ", "_").replace("'", "")
        print("Got something!")
        df.to_csv(file_name)

for player in get_best_players():
    print("Getting and writing data of " + player + "...")
    get_and_write_data(player)

print("Done!")
# Out:
# Getting and writing data of Kareem Abdul-Jabbar...
# Got something!
# Got something!
# Getting and writing data of Nate Archibald...
# Got something!
# Got something!
# Getting and writing data of Paul Arizin...
# Got something!
# Got something!
# Getting and writing data of Charles Barkley...
# Got something!
# Got something!
# Getting and writing data of Rick Barry...
# Got something!
# Getting and writing data of Elgin Baylor...
# Got something!
# Got something!
# Getting and writing data of Dave Bing...
# Got something!
# Got something!
# Getting and writing data of Larry Bird...
# Got something!
# Got something!
# Getting and writing data of Wilt Chamberlain...
# Got something!
# Got something!
# Getting and writing data of Bob Cousy...
# Got something!
# Got something!
# Getting and writing data of Dave Cowens...
# Got something!
# Got something!
# Getting and writing data of Billy Cunningham...
# Got something!
# Got something!
